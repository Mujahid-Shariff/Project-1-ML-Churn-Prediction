# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d6c68c3c-b9d2-4ca5-892b-92968812696c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6c68c3c-b9d2-4ca5-892b-92968812696c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("telecommunications_churn (1).csv")
df.head()
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0             128                1                   25     265.1
# 1             107                1                   26     161.6
# 2             137                0                    0     243.4
# 3              84                0                    0     299.4
# 4              75                0                    0     166.7
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0         197.4       244.7                10.0                       1
# 1         195.5       254.4                13.7                       1
# 2         121.2       162.6                12.2                       0
# 3          61.9       196.9                 6.6                       2
# 4         148.3       186.9                10.1                       3
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account_length          3333 non-null   int64
#  1   voice_mail_plan         3333 non-null   int64
#  2   voice_mail_messages     3333 non-null   int64
#  3   day_mins                3333 non-null   float64
#  4   evening_mins            3333 non-null   float64
#  5   night_mins              3333 non-null   float64
#  6   international_mins      3333 non-null   float64
#  7   customer_service_calls  3333 non-null   int64
#  8   international_plan      3333 non-null   int64
#  9   day_calls               3333 non-null   int64
#  10  day_charge              3333 non-null   float64
#  11  evening_calls           3333 non-null   int64
#  12  evening_charge          3333 non-null   float64
#  13  night_calls             3333 non-null   int64
# ...

# %%
upper_whisker=df['total_charge'].mean() + (3*(df['total_charge'].std()))
upper_whisker
# Out:
# 90.95653623266057

# %%
lower_whisker=df['total_charge'].mean() - (3*(df['total_charge'].std()))
lower_whisker
# Out:
# 27.942971718134515

# %%
df_out= df[(df['total_charge'] > upper_whisker) | (df['total_charge'] < lower_whisker)]
df_out

#Outlier-Acc_length=7, 2-1, 5-0(churn)
#Outlier-voice_mail_messags=3, 3-0(churn)
#Outlier-day_minutes=9, 4-1, 5-0
#Outlier-evening_minutes=9, 1-1, 8-0
#Outlier-night_minutes=11, 2-1, 9-0
#Outlier-international_minutes=22, 1-1, 21-0
#Outlier-customer_servce_calls=35, 22-1, 13-0
#Outlier-day_calls=9, 2-1, 7-0
#Outlier-Day_charge_=9, 4-1, 5-0
#Outlier-evening_cals_=7, 1-1, 6-0
#Outlier-evening_charge=9, 1-1, 8-0
#Outlier-night_cals_=6, 6-0
#Outlier-night_chrge_=11, 2-1, 9-0
#Outlier-internatinal_calls_=50, 7-1, 43-0
#Outlier-internatinal_charge_=22, 1-1, 21-0
#Outlier-Total_charge_=11, 5-1, 6-0

#Total Outliers = 237
#Total Outliers in 0 = 182
#Total Outliers in 1 = 55
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 15               161                0                    0     332.9
# 77               144                0                    0      61.6
# 365              154                0                    0     179.0
# 648              131                1                   39      69.1
# 985               64                0                    0     179.0
# 1345              98                0                    0     179.0
# 1397             101                0                    0     179.0
# 1621             138                1                   21      19.5
# 1986              70                0                    0     179.0
# 2753             134                0                    0     179.0
# 2859              87                0                    0      58.0
#
#       evening_mins  night_mins  international_mins  customer_service_calls  \
# ...

# %%
df_out.shape
# Out:
# (11, 19)

# %%
int(df['total_charge'].mean())
# Out:
# 59

# %%
import numpy as np
df["total_charge"] = np.where(df["total_charge"] >upper_whisker, int(df['total_charge'].mean()),df['total_charge'])

df["total_charge"] = np.where(df["total_charge"] <lower_whisker, int(df['total_charge'].mean()),df['total_charge'])

# %%
#min(df["total_charge"])
df['total_charge'][1986]
# Out:
# 59.0

# %%
df
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0                128                1                   25     265.1
# 1                107                1                   26     161.6
# 2                137                0                    0     243.4
# 3                 84                0                    0     299.4
# 4                 75                0                    0     166.7
# ...              ...              ...                  ...       ...
# 3328             192                1                   36     156.2
# 3329              68                0                    0     231.1
# 3330              28                0                    0     180.8
# 3331             184                0                    0     213.8
# 3332              74                1                   25     234.4
#
#       evening_mins  night_mins  international_mins  customer_service_calls  \
# ...

# %%
df.to_csv("no_out_data.csv")

# %%
df.boxplot(column="total_charge",vert=False,figsize=(15,10))
df.corr()
# Out:
#                         account_length  voice_mail_plan  voice_mail_messages  \
# account_length                1.000000         0.005085            -0.004960
# voice_mail_plan               0.005085         1.000000             0.956537
# voice_mail_messages          -0.004960         0.956537             1.000000
# day_mins                      0.009683        -0.001361            -0.001481
# evening_mins                 -0.006195         0.019902             0.018008
# night_mins                   -0.010682         0.005839             0.009645
# international_mins            0.023236        -0.006262            -0.005371
# customer_service_calls        0.001566        -0.029558            -0.027648
# international_plan            0.024049         0.006006             0.009699
# day_calls                     0.037190        -0.010823            -0.010378
# day_charge                    0.009660        -0.001315            -0.001437
# ...
